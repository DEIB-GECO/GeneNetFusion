# %% [markdown]
# # Pipeline
# Try this online https://colab.research.google.com/drive/1MPzlkCioSXXaL-EqpInR98P1QAM4lRMR

# %% [markdown]
# # This notebook contains knowledge-based evaluations for the extracted IC genes, the example has been done on LIHC results

# %%
import requests
import re
import numpy as np
import csv
import pandas as pd
import joblib
from tqdm import tqdm_notebook
import time 
import scipy.stats as stats
from openpyxl import load_workbook
from gprofiler import GProfiler

# %% [markdown]
# # Pubmed evaluation: are the IC genes enriched in cancer type publications against all genes present in the fused network?

# %%
#Functions to extract the number of publications associated to a single term (extract_single), 
#two terms with "or" condition (extract_or) and two terms with "and" condition (extract_and)
def extract_single(one):
    try:
        contains = ''
        while contains == '':
            try:
                #%5Btw%5D is used to make sure that the searching term is included in the title, abstract, other abstract, 
                #MeSH terms, MeSH Subheadings, Publication Types or Substance Names.
                contains = requests.get("https://pubmed.ncbi.nlm.nih.gov/?term=%28{}%5Btw%5D%29".format(one))
                break
            except:
                time.sleep(5)
                continue
            
        m = re.search('<meta name="log_resultcount" content="[0-9]+"', str(contains.content))
        return int(m.group(0)[38:-1])
    except:
        m1 = re.search('<meta name="log_source_db" content=".+" />',str(contains.content))
        if m1 is not None:
            return 1
        if m1 is None:
            return 0
        
def extract_or(*args):
    query = "https://pubmed.ncbi.nlm.nih.gov/?term=%28{}%5Btw%5D%29".format(args[0].replace(" ", "+"))
    for a in args[1:]:
        query += "+OR+%28{}%5Btw%5D%29".format(a.replace(" ", "+"))
    try:
        contains = ''
        while contains == '':
            try:
                contains = requests.get(query)
                break
            except:
                time.sleep(5)
                continue
        m = re.search('<meta name="log_resultcount" content="[0-9]+"', str(contains.content))
        return int(m.group(0)[38:-1])
    except:
        m1 = re.search('<meta name="log_source_db" content=".+" />',str(contains.content))
        if m1 is not None:
            return 1
        if m1 is None:
            return 0
        
def extract_and(*args): 
    query = "https://pubmed.ncbi.nlm.nih.gov/?term=%28{}%5Btw%5D%29".format(args[0].replace(" ", "+"))
    for a in args[1:]:
        query += "+AND+%28{}%5Btw%5D%29".format(a.replace(" ", "+"))
    contains = ''
    while contains == '':
        try:
            contains = requests.get(query)
            break
        except:
            time.sleep(5)
            continue
    m = re.search('<meta name="log_resultcount" content="[0-9]+"', str(contains.content))
    if m is not None:
        return int(m.group(0)[38:-1])
    if m is None:
        m1 = re.search('<meta name="log_source_db" content=".+" />',str(contains.content))
        if m1 is not None:
            return 1
        if m1 is None:
            return 0

# %%
#Results are tested on LIHC IC genes
cancer_type='lihc'

ICgenes = pd.read_csv('./Results/'+str(cancer_type)+'_ICgenes.csv', sep=';', header=None)
all_o = set(ICgenes[0])
all_t = set(ICgenes[1])
dict_o={}
dict_t={}

#Extraction of the number of publications for each gene
for i in tqdm_notebook(all_t):
        dict_t[i] = extract_single(i)
#Extraction of the number of publications for the cancer type
for i in tqdm_notebook(all_o):
        dict_o[i] = extract_single(i)
            
n_t_tot=[]
n_o_tot=[]
tot=[]
common=[]
name1=[]
name2=[]

#Extraction of the number of publications of the two terms (gene, cancer type)
#considering OR/AND conditions
for i,j in dict_o.items():
    for key,value in tqdm_notebook(dict_t.items()):
        n_tot = extract_or(i, key)
        n_common = extract_and(i, key)
        name1.append(key)
        name2.append(i)
        n_t_tot.append(value)
        n_o_tot.append(j)
        tot.append(n_tot)
        if n_common == n_tot:
            common.append(0)
        if n_common != n_tot:
            common.append(n_common)

#Save results in csv file:
#first column contains the gene names, second column the cancer type, 
#third column is the number of publications for each gene, fourth column contains the number of publications for the cancer type
#fifth and sixth columns contain the number of publications for condition OR and AND of the two terms gene/cancer type
df = pd.DataFrame(list(zip(name1,name2,n_t_tot,n_o_tot,tot,common)), columns =['genes', 'cancer','pubmed_genes','pubmed_cancer','OR','AND']) 
df.to_csv('./Results/'+str(t)+'_pubmedresults_ICgenes.csv', index=None, header=None)

# %%
#To compute the enrichment we need to count the cancer-type-related publications for all genes in the LIHC fused network
cancer_type='lihc'

all_genes = pd.read_csv('./Results/'+str(cancer_type)+'_allgenes.csv', sep=';', header=None)
all_o = set(all_genes[0])
all_t = set(all_genes[1])
dict_o={}
dict_t={}

#Extraction of the number of publications for each gene
for i in tqdm_notebook(all_t):
        dict_t[i] = extract_single(i)
#Extraction of the number of publications for the cancer type
for i in tqdm_notebook(all_o):
        dict_o[i] = extract_single(i)
            
n_t_tot=[]
n_o_tot=[]
tot=[]
common=[]
name1=[]
name2=[]

#Extraction of the number of publications of the two terms (gene, cancer type)
#considering OR/AND conditions
for i,j in dict_o.items():
    for key,value in tqdm_notebook(dict_t.items()):
        n_tot = extract_or(i, key)
        n_common = extract_and(i, key)
        name1.append(key)
        name2.append(i)
        n_t_tot.append(value)
        n_o_tot.append(j)
        tot.append(n_tot)
        if n_common == n_tot:
            common.append(0)
        if n_common != n_tot:
            common.append(n_common)

#Save results in csv file:
#first column contains the gene names, second column the cancer type, 
#third column is the number of publications for each gene, fourth column contains the number of publications for the cancer type
#fifth and sixth columns contain the number of publications for condition OR and AND of the two terms gene/cancer type
df = pd.DataFrame(list(zip(name1,name2,n_t_tot,n_o_tot,tot,common)), columns =['genes', 'cancer','pubmed_genes','pubmed_cancer','OR','AND']) 
df.to_csv('./Results/'+str(t)+'_pubmedresults_allgenes.csv', index=None, header=None)

# %%
def parse_line(l):
    try:
        s = l.strip().split(",")
        return s[0],s[1],int(s[-4]),int(s[-3]), int(s[-2]), int(s[-1])
    except:
        print(l)

# %%
#Read the previously saved files
with open('./Results/'+str(cancer_type)+'_pubmedresults_ICgenes.csv') as f:
    all_lines = [parse_line(l) for l in f.readlines()]
with open('./Results/'+str(cancer_type)+'_pubmedresults_allgenes.csv') as f:
    all_all = [parse_line(l) for l in f.readlines()]

# %%
print(len(all_all))
print(len(all_lines))
# Out:
# 13012
# 839

# %%
#Extract the number of publications for the two terms (gene/cancer type) with AND condition
def pub_and(all_l):
    y = []
    x = list(range(len(all_l)))
    for i in x:
        y.append([int(x[-1]) for x in all_l])
    return np.array(y),x

# %%
y_all,_ = pub_and(all_all)
y_IC,_ = pub_and(all_lines)
k=len(np.nonzero(y_IC[0])[0])
M=len(np.nonzero(y_all[0])[0])
N=len(all_all)
s=len(all_lines)

# %%
#Fisher's exact test to demostrate that the IC genes are enriched for cancer-type-specific publications
_, pvalue = stats.fisher_exact([[k, s-k],[M-k, N-(M-k)]])  
print(pvalue)
# Out:
# 1.045115648264007e-12

# %% [markdown]
# # DrugBank evaluation: are the IC genes enriched in druggable targets against all other genes in the network?

# %%
#The file DB_pharmacologically_active.csv is directly downloaded from DrugBank
DrugBank=pd.read_csv("./Supplementary data/DB_pharmacologically_active.csv")

# %%
#The count_DrugBank function is used to extract the pharmacologically active targets among the input list of genes
def count_DrugBank(data):
    res=[]
    for i in data:
        if any(DrugBank['Gene Name']==i):
            res.append(DrugBank[DrugBank['Gene Name']==i])
    res=pd.concat(res)
    res=res.reset_index(drop=True)
    return res

# %%
DB_ICgenes = count_DrugBank(ICgenes[1])
#Print the total number of actionable IC genes
print(len(set(DB_ICgenes['Gene Name'])))
#Print the total number of IC genes
print(len(set(ICgenes[1])))
# Out:
# 69
# 839

# %%
DB_allgenes = count_DrugBank(all_genes[1])
#Print the total number of actionable genes from the fused networl
print(len(set(DB_allgenes['Gene Name'])))
#Print the total number of genes from the fused network
print(len(set(all_genes[1])))
# Out:
# 481
# 13011

# %%
#Fisher's exact test to demostrate that the IC genes are enriched in druggable targets
k=len(set(DB_ICgenes['Gene Name']))
s=len(set(ICgenes[1]))
M=len(set(DB_allgenes['Gene Name']))
N=len(set(all_genes[1]))
_, pvalue = stats.fisher_exact([[k, s-k],[(M)-k, (N)-((M)-k)]])  
print(pvalue)
# Out:
# 1.5976548100792317e-11

# %% [markdown]
# # g:Profiler Enrichment analysis of the IC genes

# %%
#Using g:Profiler we perform enrichment analysis on the IC genes
gp = GProfiler(return_dataframe=True)
gp_comm=gp.profile(organism='hsapiens', query=list(ICgenes[1]),no_evidences=False)
gp_comm.to_csv('./Enrichment_'+str(cancer_type)+'_ICgenes.csv')

# %%
gp_comm
# Out:
#     source              native  \
# 0     REAC  REAC:R-HSA-1430728
# 1    GO:BP          GO:0055114
# 2    GO:MF          GO:0016491
# 3    GO:BP          GO:0046395
# 4    GO:BP          GO:0016054
# 5    GO:BP          GO:0044281
# 6    GO:CC          GO:0005739
# 7    GO:BP          GO:0044282
# 8    GO:BP          GO:0019752
# 9    GO:BP          GO:0043436
# 10   GO:BP          GO:0006082
# 11    KEGG          KEGG:01100
# 12    REAC    REAC:R-HSA-71291
# 13   GO:BP          GO:0022900
# 14   GO:CC          GO:0005743
# 15   GO:CC          GO:0005759
# 16   GO:BP          GO:0032787
# 17   GO:CC          GO:0019866
# 18   GO:CC          GO:0005740
# 19   GO:BP          GO:0022904
# 20   GO:BP          GO:0006091
# 21   GO:BP          GO:1901575
# 22   GO:CC          GO:0031966
# 23   GO:BP          GO:0009056
# 24   GO:BP          GO:0072329
# 25   GO:BP          GO:0044248
# 26   GO:BP          GO:0017144
# 27    REAC   REAC:R-HSA-611105
# 28   GO:BP          GO:0009063
# 29   GO:CC          GO:0070469
# ..     ...                 ...
# 891  GO:BP          GO:0046874
# 892  GO:BP          GO:0006572
# 893  GO:BP          GO:0010901
# 894  GO:BP          GO:0043691
# 895  GO:BP          GO:0006067
# 896  GO:MF          GO:0017171
# 897  GO:MF          GO:0016825
# 898   REAC   REAC:R-HSA-159740
# 899   REAC   REAC:R-HSA-159782
# 900     HP          HP:0004431
# 901   KEGG          KEGG:00360
# 902  CORUM          CORUM:2905
# 903     HP          HP:0010895
# 904  GO:BP          GO:0001936
# 905  GO:BP          GO:0006956
# 906   REAC  REAC:R-HSA-5365859
# 907  GO:MF          GO:0061134
# 908  GO:MF          GO:0071949
# 909  GO:MF          GO:0016229
# 910  GO:BP          GO:1901607
# 911     HP          HP:0001397
# 912  GO:BP          GO:0000098
# 913     TF         TF:M10055_1
# 914   REAC   REAC:R-HSA-159418
# 915  GO:BP          GO:0090050
# 916  CORUM          CORUM:6417
# 917  CORUM          CORUM:6405
# 918  GO:MF          GO:0004165
# 919  GO:MF          GO:0008431
# 920  GO:MF          GO:0070653
#
#                                                   name       p_value  \
# 0                                           Metabolism  4.866241e-87
# 1                          oxidation-reduction process  3.009886e-82
# 2                              oxidoreductase activity  1.542436e-73
# 3                    carboxylic acid catabolic process  4.026219e-65
# 4                       organic acid catabolic process  4.026219e-65
# 5                     small molecule metabolic process  6.617864e-62
# 6                                        mitochondrion  3.312159e-60
# 7                     small molecule catabolic process  8.601402e-60
# 8                    carboxylic acid metabolic process  3.406416e-58
# 9                            oxoacid metabolic process  5.231939e-57
# 10                      organic acid metabolic process  1.526251e-56
# 11                                  Metabolic pathways  1.763580e-48
# 12           Metabolism of amino acids and derivatives  4.121741e-44
# 13                            electron transport chain  1.750555e-43
# 14                        mitochondrial inner membrane  1.051425e-42
# 15                                mitochondrial matrix  1.133647e-40
# 16               monocarboxylic acid metabolic process  1.379676e-39
# 17                            organelle inner membrane  2.497385e-39
# 18                              mitochondrial envelope  3.184945e-39
# 19                respiratory electron transport chain  5.605852e-37
# 20      generation of precursor metabolites and energy  2.109517e-36
# 21                 organic substance catabolic process  2.408112e-36
# 22                              mitochondrial membrane  4.077199e-36
# 23                                   catabolic process  8.014430e-36
# 24               monocarboxylic acid catabolic process  1.388879e-35
# 25                          cellular catabolic process  4.903740e-35
# 26                              drug metabolic process  1.047816e-34
# 27                      Respiratory electron transport  7.567367e-34
# 28               cellular amino acid catabolic process  2.391782e-33
# 29                                         respirasome  5.293353e-33
# ..                                                 ...           ...
# 891                      quinolinate metabolic process  3.593839e-02
# 892                         tyrosine catabolic process  3.593839e-02
# 893  regulation of very-low-density lipoprotein par...  3.593839e-02
# 894                      reverse cholesterol transport  3.657633e-02
# 895                          ethanol metabolic process  3.657633e-02
# 896                          serine hydrolase activity  3.725912e-02
# 897  hydrolase activity, acting on acid phosphorus-...  3.725912e-02
# 898          Gamma-carboxylation of protein precursors  3.740293e-02
# 899  Removal of aminoterminal propeptides from gamm...  3.740293e-02
# 900                              Complement deficiency  3.865265e-02
# 901                           Phenylalanine metabolism  3.897963e-02
# 902  Respiratory chain complex I (intermediate), mi...  4.008476e-02
# 903         Abnormal circulating glycine concentration  4.093377e-02
# 904       regulation of endothelial cell proliferation  4.190408e-02
# 905                              complement activation  4.190408e-02
# 906                            RA biosynthesis pathway  4.232697e-02
# 907                       peptidase regulator activity  4.271062e-02
# 908                                        FAD binding  4.319968e-02
# 909                     steroid dehydrogenase activity  4.319968e-02
# 910              alpha-amino acid biosynthetic process  4.499553e-02
# 911                                  Hepatic steatosis  4.566141e-02
# 912                sulfur amino acid catabolic process  4.607695e-02
# 913  Factor: RXR-alpha; motif: NNGNNRNNNARAGGTCANNG...  4.656763e-02
# 914                  Recycling of bile acids and salts  4.881600e-02
# 915  positive regulation of cell migration involved...  4.895846e-02
# 916                                 Fibrinogen complex  4.973539e-02
# 917                        MITRAC12-SURF1-COX1 complex  4.973539e-02
# 918            dodecenoyl-CoA delta-isomerase activity  4.981318e-02
# 919                                  vitamin E binding  4.981318e-02
# 920  high-density lipoprotein particle receptor bin...  4.981318e-02
#
#      significant                                        description  \
# 0           True                                         Metabolism
# 1           True  "A metabolic process that results in the remov...
# 2           True  "Catalysis of an oxidation-reduction (redox) r...
# 3           True  "The chemical reactions and pathways resulting...
# 4           True  "The chemical reactions and pathways resulting...
# 5           True  "The chemical reactions and pathways involving...
# 6           True  "A semiautonomous, self replicating organelle ...
# 7           True  "The chemical reactions and pathways resulting...
# 8           True  "The chemical reactions and pathways involving...
# 9           True  "The chemical reactions and pathways involving...
# 10          True  "The chemical reactions and pathways involving...
# 11          True                                 Metabolic pathways
# 12          True          Metabolism of amino acids and derivatives
# 13          True  "A process in which a series of electron carri...
# 14          True  "The inner, i.e. lumen-facing, lipid bilayer o...
# 15          True  "The gel-like material, with considerable fine...
# 16          True  "The chemical reactions and pathways involving...
# 17          True  "The inner, i.e. lumen-facing, lipid bilayer o...
# 18          True  "The double lipid bilayer enclosing the mitoch...
# 19          True  "A process in which a series of electron carri...
# 20          True  "The chemical reactions and pathways resulting...
# 21          True  "The chemical reactions and pathways resulting...
# 22          True  "Either of the lipid bilayers that surround th...
# 23          True  "The chemical reactions and pathways resulting...
# 24          True  "The chemical reactions and pathways resulting...
# 25          True  "The chemical reactions and pathways resulting...
# 26          True  "The chemical reactions and pathways involving...
# 27          True                     Respiratory electron transport
# 28          True  "The chemical reactions and pathways resulting...
# 29          True  "The protein complexes that form the electron ...
# ..           ...                                                ...
# 891         True  "The chemical reactions and pathways involving...
# 892         True  "The chemical reactions and pathways resulting...
# 893         True  "Any process that modulates the rate, frequenc...
# 894         True  "The directed movement of peripheral cell chol...
# 895         True  "The chemical reactions and pathways involving...
# 896         True  "Catalysis of the hydrolysis of a substrate by...
# 897         True  "Catalysis of the hydrolysis of any acid phosp...
# 898         True          Gamma-carboxylation of protein precursors
# 899         True  Removal of aminoterminal propeptides from gamm...
# 900         True  An immunodeficiency defined by the absent or s...
# 901         True                           Phenylalanine metabolism
# 902         True  Respiratory chain complex I (intermediate), mi...
# 903         True  Any deviation from the normal concentration of...
# 904         True  "Any process that modulates the frequency, rat...
# 905         True  "Any process involved in the activation of any...
# 906         True                            RA biosynthesis pathway
# 907         True  "Modulates the activity of a peptidase, any en...
# 908         True  "Interacting selectively and non-covalently wi...
# 909         True  "Catalysis of an oxidation-reduction (redox) r...
# 910         True  "The chemical reactions and pathways resulting...
# 911         True            The presence of steatosis in the liver.
# 912         True  "The chemical reactions and pathways resulting...
# 913         True  Factor: RXR-alpha; motif: NNGNNRNNNARAGGTCANNG...
# 914         True                  Recycling of bile acids and salts
# 915         True  "Any process that increases the frequency, rat...
# 916         True                                 Fibrinogen complex
# 917         True                        MITRAC12-SURF1-COX1 complex
# 918         True  "Catalysis of the reaction: 3-cis-dodecenoyl-C...
# 919         True  "Interacting selectively and non-covalently wi...
# 920         True  "Interacting selectively and non-covalently wi...
#
#      term_size  query_size  intersection_size  effective_domain_size  \
# 0         2072         553                315                  10594
# 1         1028         745                204                  17906
# 2          768         761                169                  18126
# 3          276         745                101                  17906
# 4          276         745                101                  17906
# 5         1987         745                253                  17906
# 6         1631         774                223                  18856
# 7          447         745                119                  17906
# 8         1066         745                178                  17906
# 9         1157         745                184                  17906
# 10        1177         745                185                  17906
# 11        1482         475                229                   7788
# 12         368         553                101                  10594
# 13         188         745                 69                  17906
# 14         482         774                103                  18856
# 15         476         774                100                  18856
# 16         661         745                118                  17906
# 17         543         774                105                  18856
# 18         766         774                125                  18856
# 19         118         745                 52                  17906
# 20         544         745                103                  17906
# 21        2239         745                226                  17906
# 22         723         774                117                  18856
# 23        2693         745                252                  17906
# 24         130         745                 53                  17906
# 25        2314         745                228                  17906
# 26         600         745                106                  17906
# 27         100         553                 49                  10594
# 28         129         745                 51                  17906
# 29         101         774                 45                  18856
# ..         ...         ...                ...                    ...
# 891          5         745                  4                  17906
# 892          5         745                  4                  17906
# 893          5         745                  4                  17906
# 894         21         745                  7                  17906
# 895         21         745                  7                  17906
# 896        191         761                 21                  18126
# 897        191         761                 21                  18126
# 898         10         553                  5                  10594
# 899         10         553                  5                  10594
# 900         27         271                  9                   4225
# 901         17         475                  6                   7788
# 902         11         174                  5                   3629
# 903         16         271                  7                   4225
# 904        178         745                 21                  17906
# 905        178         745                 21                  17906
# 906         22         553                  7                  10594
# 907        222         761                 23                  18126
# 908         34         761                  8                  18126
# 909         34         761                  8                  18126
# 910         67         745                 12                  17906
# 911        106         271                 19                   4225
# 912         15         745                  6                  17906
# 913       1104         743                 70                  19945
# 914         16         553                  6                  10594
# 915         38         745                  9                  17906
# 916          3         174                  3                   3629
# 917          3         174                  3                   3629
# 918          3         761                  3                  18126
# 919          3         761                  3                  18126
# 920          3         761                  3                  18126
#
#      precision    recall    query  \
# 0     0.569620  0.152027  query_1
# 1     0.273826  0.198444  query_1
# 2     0.222076  0.220052  query_1
# 3     0.135570  0.365942  query_1
# 4     0.135570  0.365942  query_1
# 5     0.339597  0.127328  query_1
# 6     0.288114  0.136726  query_1
# 7     0.159732  0.266219  query_1
# 8     0.238926  0.166979  query_1
# 9     0.246980  0.159032  query_1
# 10    0.248322  0.157179  query_1
# 11    0.482105  0.154521  query_1
# 12    0.182640  0.274457  query_1
# 13    0.092617  0.367021  query_1
# 14    0.133075  0.213693  query_1
# 15    0.129199  0.210084  query_1
# 16    0.158389  0.178517  query_1
# 17    0.135659  0.193370  query_1
# 18    0.161499  0.163185  query_1
# 19    0.069799  0.440678  query_1
# 20    0.138255  0.189338  query_1
# 21    0.303356  0.100938  query_1
# 22    0.151163  0.161826  query_1
# 23    0.338255  0.093576  query_1
# 24    0.071141  0.407692  query_1
# 25    0.306040  0.098531  query_1
# 26    0.142282  0.176667  query_1
# 27    0.088608  0.490000  query_1
# 28    0.068456  0.395349  query_1
# 29    0.058140  0.445545  query_1
# ..         ...       ...      ...
# 891   0.005369  0.800000  query_1
# 892   0.005369  0.800000  query_1
# 893   0.005369  0.800000  query_1
# 894   0.009396  0.333333  query_1
# 895   0.009396  0.333333  query_1
# 896   0.027595  0.109948  query_1
# 897   0.027595  0.109948  query_1
# 898   0.009042  0.500000  query_1
# 899   0.009042  0.500000  query_1
# 900   0.033210  0.333333  query_1
# 901   0.012632  0.352941  query_1
# 902   0.028736  0.454545  query_1
# 903   0.025830  0.437500  query_1
# 904   0.028188  0.117978  query_1
# 905   0.028188  0.117978  query_1
# 906   0.012658  0.318182  query_1
# 907   0.030223  0.103604  query_1
# 908   0.010512  0.235294  query_1
# 909   0.010512  0.235294  query_1
# 910   0.016107  0.179104  query_1
# 911   0.070111  0.179245  query_1
# 912   0.008054  0.400000  query_1
# 913   0.094213  0.063406  query_1
# 914   0.010850  0.375000  query_1
# 915   0.012081  0.236842  query_1
# 916   0.017241  1.000000  query_1
# 917   0.017241  1.000000  query_1
# 918   0.003942  1.000000  query_1
# 919   0.003942  1.000000  query_1
# 920   0.003942  1.000000  query_1
#
#                                               parents  \
# 0                                      [REAC:0000000]
# 1                                        [GO:0008152]
# 2                                        [GO:0003824]
# 3                            [GO:0016054, GO:0019752]
# 4    [GO:0006082, GO:0044248, GO:0044282, GO:1901575]
# 5                                        [GO:0008152]
# 6                            [GO:0005737, GO:0043231]
# 7                            [GO:0009056, GO:0044281]
# 8                                        [GO:0043436]
# 9                                        [GO:0006082]
# 10               [GO:0044237, GO:0044281, GO:0071704]
# 11                                       [KEGG:00000]
# 12                               [REAC:R-HSA-1430728]
# 13                           [GO:0006091, GO:0055114]
# 14                           [GO:0019866, GO:0031966]
# 15                           [GO:0005739, GO:0070013]
# 16                                       [GO:0019752]
# 17                           [GO:0031090, GO:0031967]
# 18                           [GO:0005739, GO:0031967]
# 19                           [GO:0022900, GO:0045333]
# 20                                       [GO:0044237]
# 21                           [GO:0009056, GO:0071704]
# 22                           [GO:0005740, GO:0031090]
# 23                                       [GO:0008152]
# 24                           [GO:0032787, GO:0046395]
# 25                           [GO:0009056, GO:0044237]
# 26                                       [GO:0044237]
# 27                                [REAC:R-HSA-163200]
# 28               [GO:0006520, GO:0046395, GO:1901565]
# 29                           [GO:0016020, GO:0110165]
# ..                                                ...
# 891              [GO:0017144, GO:0043648, GO:0072524]
# 892              [GO:0006570, GO:0009074, GO:1901606]
# 893              [GO:0034372, GO:0051128, GO:0051239]
# 894                                      [GO:0030301]
# 895                          [GO:0016999, GO:0034308]
# 896                                      [GO:0016825]
# 897                                      [GO:0016787]
# 898                               [REAC:R-HSA-159854]
# 899                               [REAC:R-HSA-159854]
# 900                                      [HP:0005339]
# 901                                      [KEGG:00000]
# 902                                   [CORUM:0000000]
# 903                                      [HP:0010894]
# 904                          [GO:0001935, GO:0050678]
# 905              [GO:0002252, GO:0002253, GO:0006959]
# 906                              [REAC:R-HSA-5362517]
# 907                                      [GO:0030234]
# 908                                      [GO:0050660]
# 909                                      [GO:0016491]
# 910                          [GO:0008652, GO:1901605]
# 911                                      [HP:0006561]
# 912              [GO:0000096, GO:0009063, GO:0044273]
# 913                                     [TF:M10055_0]
# 914                               [REAC:R-HSA-194068]
# 915  [GO:0002042, GO:0043536, GO:0090049, GO:1903672]
# 916                                   [CORUM:0000000]
# 917                                   [CORUM:0000000]
# 918                                      [GO:0016863]
# 919              [GO:0019842, GO:0097159, GO:1901363]
# 920                                      [GO:0070325]
#
#                                          intersections  \
# 0    [NDUFAB1, SLC25A13, PON1, FMO3, MGST1, RPS20, ...
# 1    [NDUFAB1, SLC25A13, KDM7A, FMO3, MGST1, IYD, U...
# 2    [NDUFAB1, KDM7A, FMO3, MGST1, IYD, UQCRC1, HSD...
# 3    [PON1, OTC, ACAA1, HSD17B10, ACAT1, ACACB, BCK...
# 4    [PON1, OTC, ACAA1, HSD17B10, ACAT1, ACACB, BCK...
# 5    [NDUFAB1, SLC25A13, PON1, IYD, CPS1, OTC, ITIH...
# 6    [NDUFAB1, SLC25A13, MGST1, UQCRC1, CPS1, OTC, ...
# 7    [PON1, OTC, ACAA1, HAGH, HSD17B10, ACAT1, ACAC...
# 8    [NDUFAB1, PON1, IYD, CPS1, OTC, ITIH4, ITIH1, ...
# 9    [NDUFAB1, PON1, IYD, CPS1, OTC, ITIH4, ITIH1, ...
# 10   [NDUFAB1, PON1, IYD, CPS1, OTC, ITIH4, ITIH1, ...
# 11   [NDUFAB1, MGST1, UQCRC1, CPS1, HSD17B6, OTC, A...
# 12   [NDUFAB1, SLC25A13, RPS20, IYD, CPS1, OTC, RPL...
# 13   [NDUFAB1, SLC25A13, UQCRC1, HSD17B6, MAOB, NDU...
# 14   [NDUFAB1, SLC25A13, UQCRC1, CPS1, OTC, MRPS34,...
# 15   [NDUFAB1, CPS1, OTC, HAGH, ACSM2B, HSD17B10, M...
# 16   [NDUFAB1, PON1, ACAA1, HAGH, ACSM2B, ACAT1, AC...
# 17   [NDUFAB1, SLC25A13, UQCRC1, CPS1, OTC, MRPS34,...
# 18   [NDUFAB1, SLC25A13, MGST1, UQCRC1, CPS1, OTC, ...
# 19   [NDUFAB1, SLC25A13, UQCRC1, NDUFB2, ETFB, COX6...
# 20   [NDUFAB1, SLC25A13, UQCRC1, HSD17B6, MAOB, ACA...
# 21   [PON1, RPS20, ZRANB1, CPS1, HSD17B6, OTC, AP2S...
# 22   [NDUFAB1, SLC25A13, MGST1, UQCRC1, CPS1, OTC, ...
# 23   [PON1, RPS20, ZRANB1, CPS1, HSD17B6, OTC, AP2S...
# 24   [ACAA1, ACAT1, ACACB, CRAT, PCK2, LONP2, MLYCD...
# 25   [PON1, RPS20, ZRANB1, CPS1, OTC, AP2S1, ACAA1,...
# 26   [SLC25A13, CPS1, ACAA1, MAOB, RORA, ST6GAL1, A...
# 27   [NDUFAB1, UQCRC1, NDUFB2, ETFB, COX6A1, NDUFS7...
# 28   [OTC, HSD17B10, ACAT1, BCKDHB, TXN2, GSTZ1, FA...
# 29   [NDUFAB1, UQCRC1, NDUFB2, COX6A1, COX7A2, NNT,...
# ..                                                 ...
# 891                           [QPRT, KMO, ACMSD, HAAO]
# 892                             [GSTZ1, FAH, HGD, HPD]
# 893                       [APOA5, APOC3, APOA1, APOA2]
# 894     [APOC3, APOA1, APOE, APOA2, ABCA1, APOM, LCAT]
# 895  [SULT2A1, ALDH2, ADH6, ADH1A, ADH1B, SULT1A2, ...
# 896  [MASP2, F7, F11, LONP2, HPN, HGFAC, PROC, CLPP...
# 897  [MASP2, F7, F11, LONP2, HPN, HGFAC, PROC, CLPP...
# 898                         [F7, PROC, F10, F2, PROS1]
# 899                         [F7, PROC, F10, F2, PROS1]
# 900        [CFH, MASP2, C6, C5, C9, C3, C1R, CFI, CFB]
# 901                [MAOB, GOT1, GOT2, GLYAT, HPD, PAH]
# 902           [NDUFS7, NDUFA2, NDUFS5, NDUFV2, NDUFS3]
# 903         [PNPO, PCCB, MMAB, AMT, MUT, MMAA, GLYCTK]
# 904  [APOH, PROX1, APOE, XDH, LRG1, ANG, hsa-mir-10...
# 905  [CFH, MASP2, C6, CPB2, C5, VTN, C9, C4BPB, C3,...
# 906  [ALDH8A1, RDH5, RDH16, DHRS4, DHRS3, ADH1A, ADH4]
# 907  [ITIH4, ITIH1, PEBP1, FETUB, SERPIND1, SERPINA...
# 908  [DAO, KMO, AOX1, XDH, ACOX1, LDHD, ACOX2, PRODH2]
# 909  [HSD17B6, HSD17B10, HSD3B7, HSD17B4, RDH5, RDH...
# 910  [CPS1, OTC, MTHFD1, AGXT2, GOT1, GOT2, BHMT2, ...
# 911  [SLC25A13, PGM1, APOB, PCK2, ETFB, ACADM, ATP7...
# 912             [TXN2, PCYOX1, MPST, TST, CDO1, MAT1A]
# 913  [IL32, SLC6A13, PEBP1, HSD3B7, EMC9, SEC23A, S...
# 914     [SLC27A5, SLC10A1, SLCO1B1, BAAT, ALB, STARD5]
# 915  [hsa-mir-101-1, hsa-mir-101-2, hsa-mir-10a, hs...
# 916                                    [FGG, FGA, FGB]
# 917                              [SURF1, COA3, MT-CO1]
# 918                               [EHHADH, ECI1, ECI2]
# 919                               [AFM, SEC14L2, TTPA]
# 920                              [APOC3, APOA1, APOA2]
#
#                                              evidences
# 0    [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 1    [[TAS, NAS, IEA], [IDA, IBA, IEA], [IEA], [IEA...
# 2    [[NAS], [IDA, IEA], [IBA, IEA], [IDA], [IDA, I...
# 3    [[IDA], [IDA], [IMP, IBA, TAS], [TAS], [IMP, I...
# 4    [[IDA], [IDA], [IMP, IBA, TAS], [TAS], [IMP, I...
# 5    [[NAS, IEA], [IDA, TAS], [IDA, TAS, IEA], [IDA...
# 6    [[IDA, ISS, IBA, TAS, NAS, IEA], [IDA, ISS, TA...
# 7    [[IDA], [IDA], [IMP, IBA, TAS], [IEA], [TAS], ...
# 8    [[NAS, IEA], [IDA, TAS], [IDA, IBA], [IDA, IBA...
# 9    [[NAS, IEA], [IDA, TAS], [IDA, IBA], [IDA, IBA...
# 10   [[NAS, IEA], [IDA, TAS], [IDA, IBA], [IDA, IBA...
# 11   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG...
# 12   [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 13   [[TAS, NAS], [IDA, IBA, IEA], [IBA, TAS, IEA],...
# 14   [[IDA, ISS, TAS, NAS], [ISS, TAS, IEA], [IBA, ...
# 15   [[IDA, ISS], [IDA, TAS], [TAS, NAS, IEA], [IEA...
# 16   [[NAS, IEA], [TAS], [IMP, IBA, TAS, IEA], [TAS...
# 17   [[IDA, ISS, TAS, NAS], [ISS, TAS, IEA], [IBA, ...
# 18   [[IDA, ISS, TAS, NAS], [ISS, TAS, IEA], [IEA],...
# 19   [[TAS, NAS], [IDA, IBA, IEA], [IBA, TAS, IEA],...
# 20   [[TAS, NAS], [IDA, IBA, IEA], [IBA, TAS, IEA],...
# 21   [[IDA], [TAS], [IMP, IBA], [IMP], [TAS], [IDA]...
# 22   [[IDA, ISS, TAS, NAS], [ISS, TAS, IEA], [IEA],...
# 23   [[IDA], [TAS], [IMP, IBA], [IMP], [TAS], [IDA]...
# 24   [[IMP, IBA, TAS], [IBA, IEA], [IEA], [TAS], [I...
# 25   [[IDA], [TAS], [IMP, IBA], [IMP], [IDA], [TAS]...
# 26   [[IDA], [IMP], [TAS], [TAS, NAS, IEA], [IEA], ...
# 27   [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 28   [[IDA], [TAS], [IMP, TAS], [IMP, IBA, TAS], [T...
# 29   [[IDA, ISS, NAS, IEA], [TAS, IEA], [IDA, IBA, ...
# ..                                                 ...
# 891  [[IDA, IBA, IEA], [IEA], [IDA, IEA], [IDA, IBA...
# 892  [[IEA], [IBA, TAS, IEA], [TAS, IEA], [ISS, IBA...
# 893                   [[IDA], [IDA, IC], [IDA], [IDA]]
# 894  [[IC], [IMP, IBA], [IDA], [IDA], [IMP, IEA], [...
# 895  [[IDA], [TAS, IEA], [IDA, IBA, TAS], [IBA, TAS...
# 896  [[IDA, IBA, IEA], [IDA, TAS, IEA], [TAS, NAS, ...
# 897  [[IDA, IBA, IEA], [IDA, TAS, IEA], [TAS, NAS, ...
# 898           [[REAC], [REAC], [REAC], [REAC], [REAC]]
# 899           [[REAC], [REAC], [REAC], [REAC], [REAC]]
# 900  [[HP], [HP], [HP], [HP], [HP], [HP], [HP], [HP...
# 901   [[KEGG], [KEGG], [KEGG], [KEGG], [KEGG], [KEGG]]
# 902      [[CORUM], [CORUM], [CORUM], [CORUM], [CORUM]]
# 903         [[HP], [HP], [HP], [HP], [HP], [HP], [HP]]
# 904  [[IDA], [IDA], [IDA], [IDA], [IEA], [IDA], [ID...
# 905  [[IDA, TAS, IEA], [IDA, TAS, IEA], [TAS, IEA],...
# 906  [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC...
# 907  [[TAS, IEA], [IEA], [IEA], [ISS, IBA, IEA], [I...
# 908  [[IDA, IEA], [IDA, IEA], [IEA], [IEA], [IEA], ...
# 909  [[IEA], [IDA, TAS, IEA], [TAS, NAS, IEA], [IDA...
# 910  [[NAS], [IDA, IBA, IEA], [IMP, IEA], [IDA], [I...
# 911  [[HP], [HP], [HP], [HP], [HP], [HP], [HP], [HP...
# 912  [[TAS], [IEA], [TAS], [TAS], [IBA, TAS, IEA], ...
# 913  [[TF], [TF], [TF], [TF], [TF], [TF], [TF], [TF...
# 914   [[REAC], [REAC], [REAC], [REAC], [REAC], [REAC]]
# 915  [[IDA], [IDA], [IGI], [IGI], [IDA, ISS], [IGI]...
# 916                        [[CORUM], [CORUM], [CORUM]]
# 917                        [[CORUM], [CORUM], [CORUM]]
# 918                         [[IEA], [NAS, IEA], [IEA]]
# 919     [[IDA, IPI, IBA], [NAS], [ISS, IBA, TAS, IEA]]
# 920               [[IPI, IBA], [IPI, IBA], [IPI, IBA]]
#
# [921 rows x 16 columns]
